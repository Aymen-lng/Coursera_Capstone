# %% [markdown]
# # **The Battle of Neighborhoods Capstone - Final Project**
#
# <p align="center">
#   <img width="460" height="300" src="https://foter.com/photos/395/bedroom-in-hotel.jpg">
# </p>
#
# Photo on Foter.com

# %% [markdown]
# ## **Adding neighborhoods' informations when choosing a hotel or Airbnb location**

# %% [markdown]
# This note book provide an example on how to use [Foursquare API](https://foursquare.com/).
#
# It contains:
#
#      1. A detailed description of business problem and discussion of the background
#      2. A descriptions of data, its different sources and how it will solve the problem

# %% [markdown]
# ## 1 Introduction and Discussion of the Business Objective and Problem¶

# %% [markdown]
# ### The usual research of hotels or airbnb

# %% [markdown]
# #### What's the common point between below airbnb in Paris result :
#
# <p align="center">
#   <img width="460" height="300" src="https://github.com/Aymen-lng/Coursera_Capstone/blob/master/Capture5.PNG?raw=true">
# </p>
#
# #### and below google result for "Hotel Paris"
#
# <p align="center">
#   <img width="460" height="300" src="https://github.com/Aymen-lng/Coursera_Capstone/blob/master/Capture4.PNG?raw=true">
# </p>
#
# You get it....... ? Yes right! a total services/prices oriented results.
# What if you do not know anything about Paris different districts? Paris like New York, London or Berlin is a big, multicultural city with different life style depending on which district you are. You might be interested by an area with a lot of pubs and wine bar close to your place to avoid paying extra for a cab to go back to your place every nights. Or maybe, an calm area with a lot of green places and coffee shops to enjoy a nice view breakfast.
# So how would you choose ? I guess that you are doing like me:
#     * Or you anticipate by making researches on different districts of the city, and then choose them when booking your trip, taking the risk that no hotel or airbnb are available there.
#     * Or you search first on the best place based on prices and services proposed, then make additional researches on districts where the best results are.
#
# So the main problem is the missing informations about the different areas of a city when locking for your hotel or airbnb forcing you making different researches to just looking for a place to stay.

# %% [markdown]
# ### And what if...?

# %% [markdown]
# What if you could use a tool that shows different districts of a city based on its kind of venues and find the one that match the most with your trip mindset and shows it on a map with all airbnb and hotels present there.
# Let's keep as example the city of Paris. This city is made up of 20 different districts named "arrondissement". All of them have particularities. Some are full of coffees, restaurants, others bars, others parks and museum. If it's your first trip in Paris, you can be totally lost.
# The request is: is it possible to build and use a machine learning method to train a model that will cluster all these districts based on the categories of each venues in the district (bar,pub,museum,park etc...), then, by defining what kind of trip you want, propose you the best district and shows it in a map of Paris with all hotels and airbnb geo-located?

# %% [markdown]
# ## 2 Data

# %% [markdown]
# ### 2.1 Data sources

# %% [markdown]
# To build this tool we will need following informations (you can click on links) :
#
# + Paris district location. 20 different districts also known as "arrondissements" that will be used as cluster. We need their exact localization in order to map them. [Open Data Paris](https://opendata.paris.fr/explore/dataset/arrondissements/table/?dataChart)
# + Venues categories and Hotel localization. By using this api we will get all the venues in each neighborhood : [Foursquare API](https://foursquare.com/)
# + Airbnb localization : [Open Data Paris](https://data.opendatasoft.com/explore/dataset/airbnb-averages%40public/export/?disjunctive.room_type&sort=date&refine.location=France,+Paris)

# %% [markdown]
# ### 2.2 Data approach

# %% [markdown]
# With Paris districts data, we will be able to localize and identified them in a map of Paris.
# Using Foursqure data, we will be able to analye all the diferente venues categories grouped by districts.
# FInaly with foursquare again and Airbnb open data, we will be able to identified the place to stay by district.

# %% [markdown]
# ## 3 Methodology

# %% [markdown]
# ### Step 1: Libraries import

# %%
# !pip install beautifulsoup4
import numpy as np # library to handle data in a vectorized manner
import json # library to handle JSON files
import pandas as pd

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
# !conda install -c conda-forge folium=0.5.0 --yes 
import folium # map rendering library
from bs4 import BeautifulSoup

# Import k-means from clustering stage
from sklearn.cluster import KMeans



print('Libraries imported.')
# Out:
# Collecting beautifulsoup4
#   Downloading https://files.pythonhosted.org/packages/e8/b5/7bb03a696f2c9b7af792a8f51b82974e51c268f15e925fc834876a4efa0b/beautifulsoup4-4.9.0-py3-none-any.whl (109kB)
#      |████████████████████████████████| 112kB 8.2MB/s eta 0:00:01
# Collecting soupsieve>1.2 (from beautifulsoup4)
#   Downloading https://files.pythonhosted.org/packages/05/cf/ea245e52f55823f19992447b008bcbb7f78efc5960d77f6c34b5b45b36dd/soupsieve-2.0-py2.py3-none-any.whl
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.9.0 soupsieve-2.0
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %% [markdown]
# ### Step 2: Data Analysis

# %% [markdown]
# #### Data cleaning and preparation

# %%
# Paris diistricts data will be download from 'https://opendata.paris.fr/explore/dataset/arrondissements/table/?dataChart'
# then upload into a github repository in order to get them avialable for this project.
# The format used is CSV

paris = pd.read_csv('https://raw.githubusercontent.com/Aymen-lng/Coursera_Capstone/master/Arrondissements%20(1).csv')
paris
# Out:
#       N_SQ_AR  C_AR  C_ARINSEE        L_AR              L_AROFF    N_SQ_CO  \
# 0   750000005     5      75105   5ème Ardt             Panthéon  750001537
# 1   750000006     6      75106   6ème Ardt           Luxembourg  750001537
# 2   750000012    12      75112  12ème Ardt              Reuilly  750001537
# 3   750000009     9      75109   9ème Ardt                Opéra  750001537
# 4   750000019    19      75119  19ème Ardt      Buttes-Chaumont  750001537
# 5   750000015    15      75115  15ème Ardt            Vaugirard  750001537
# 6   750000002     2      75102   2ème Ardt               Bourse  750001537
# 7   750000017    17      75117  17ème Ardt  Batignolles-Monceau  750001537
# 8   750000003     3      75103   3ème Ardt               Temple  750001537
# 9   750000011    11      75111  11ème Ardt           Popincourt  750001537
# 10  750000013    13      75113  13ème Ardt             Gobelins  750001537
# 11  750000010    10      75110  10ème Ardt             Entrepôt  750001537
# 12  750000016    16      75116  16ème Ardt                Passy  750001537
# 13  750000007     7      75107   7ème Ardt       Palais-Bourbon  750001537
# 14  750000004     4      75104   4ème Ardt       Hôtel-de-Ville  750001537
# 15  750000008     8      75108   8ème Ardt               Élysée  750001537
# 16  750000018    18      75118  18ème Ardt    Buttes-Montmartre  750001537
# 17  750000014    14      75114  14ème Ardt         Observatoire  750001537
# 18  750000020    20      75120  20ème Ardt         Ménilmontant  750001537
# 19  750000001     1      75101    1er Ardt               Louvre  750001537
#
#          SURFACE     PERIMETRE                  Geometry X Y
# 0   2.539375e+06   6239.195396  48.8444431505, 2.35071460958
# 1   2.153096e+06   6483.686786  48.8491303586, 2.33289799905
# 2   1.631478e+07  24089.666300  48.8349743815, 2.42132490078
# 3   2.178303e+06   6471.588290  48.8771635173, 2.33745754348
# 4   6.792651e+06  11253.182480  48.8870759966, 2.38482096015
# 5   8.494994e+06  13678.798310  48.8400853759, 2.29282582242
# 6   9.911537e+05   4554.104360  48.8682792225, 2.34280254689
# 7   5.668835e+06  10775.579520   48.887326522, 2.30677699057
# 8   1.170883e+06   4519.263648     48.86287238, 2.3600009859
# 9   3.665442e+06   8282.011886   48.8590592213, 2.3800583082
# 10  7.149311e+06  11546.546530  48.8283880317, 2.36227244042
# 11  2.891739e+06   6739.375055  48.8761300365, 2.36072848785
# 12  1.637254e+07  17416.109660  48.8603921054, 2.26197078836
# 13  4.090057e+06   8099.424883  48.8561744288, 2.31218769148
# 14  1.600586e+06   5420.908434  48.8543414263, 2.35762962032
# 15  3.880036e+06   7880.533268   48.8727208374, 2.3125540224
# 16  5.996051e+06   9916.464176   48.892569268, 2.34816051956
# 17  5.614877e+06  10317.483310   48.8292445005, 2.3265420442
# 18  5.983446e+06  10704.940490  48.8634605789, 2.40118812928
# 19  1.824613e+06   6054.936862  48.8625627018, 2.33644336205

# %%
# Let separate last column "Geometry XY" into two columns
paris = paris.join(paris['Geometry X Y'].str.split(',',1,expand=True))
paris.shape
paris
# Out:
#       N_SQ_AR  C_AR  C_ARINSEE        L_AR              L_AROFF    N_SQ_CO  \
# 0   750000005     5      75105   5ème Ardt             Panthéon  750001537
# 1   750000006     6      75106   6ème Ardt           Luxembourg  750001537
# 2   750000012    12      75112  12ème Ardt              Reuilly  750001537
# 3   750000009     9      75109   9ème Ardt                Opéra  750001537
# 4   750000019    19      75119  19ème Ardt      Buttes-Chaumont  750001537
# 5   750000015    15      75115  15ème Ardt            Vaugirard  750001537
# 6   750000002     2      75102   2ème Ardt               Bourse  750001537
# 7   750000017    17      75117  17ème Ardt  Batignolles-Monceau  750001537
# 8   750000003     3      75103   3ème Ardt               Temple  750001537
# 9   750000011    11      75111  11ème Ardt           Popincourt  750001537
# 10  750000013    13      75113  13ème Ardt             Gobelins  750001537
# 11  750000010    10      75110  10ème Ardt             Entrepôt  750001537
# 12  750000016    16      75116  16ème Ardt                Passy  750001537
# 13  750000007     7      75107   7ème Ardt       Palais-Bourbon  750001537
# 14  750000004     4      75104   4ème Ardt       Hôtel-de-Ville  750001537
# 15  750000008     8      75108   8ème Ardt               Élysée  750001537
# 16  750000018    18      75118  18ème Ardt    Buttes-Montmartre  750001537
# 17  750000014    14      75114  14ème Ardt         Observatoire  750001537
# 18  750000020    20      75120  20ème Ardt         Ménilmontant  750001537
# 19  750000001     1      75101    1er Ardt               Louvre  750001537
#
#          SURFACE     PERIMETRE                  Geometry X Y              0  \
# 0   2.539375e+06   6239.195396  48.8444431505, 2.35071460958  48.8444431505
# 1   2.153096e+06   6483.686786  48.8491303586, 2.33289799905  48.8491303586
# 2   1.631478e+07  24089.666300  48.8349743815, 2.42132490078  48.8349743815
# 3   2.178303e+06   6471.588290  48.8771635173, 2.33745754348  48.8771635173
# 4   6.792651e+06  11253.182480  48.8870759966, 2.38482096015  48.8870759966
# 5   8.494994e+06  13678.798310  48.8400853759, 2.29282582242  48.8400853759
# 6   9.911537e+05   4554.104360  48.8682792225, 2.34280254689  48.8682792225
# 7   5.668835e+06  10775.579520   48.887326522, 2.30677699057   48.887326522
# 8   1.170883e+06   4519.263648     48.86287238, 2.3600009859    48.86287238
# 9   3.665442e+06   8282.011886   48.8590592213, 2.3800583082  48.8590592213
# 10  7.149311e+06  11546.546530  48.8283880317, 2.36227244042  48.8283880317
# 11  2.891739e+06   6739.375055  48.8761300365, 2.36072848785  48.8761300365
# 12  1.637254e+07  17416.109660  48.8603921054, 2.26197078836  48.8603921054
# 13  4.090057e+06   8099.424883  48.8561744288, 2.31218769148  48.8561744288
# 14  1.600586e+06   5420.908434  48.8543414263, 2.35762962032  48.8543414263
# 15  3.880036e+06   7880.533268   48.8727208374, 2.3125540224  48.8727208374
# 16  5.996051e+06   9916.464176   48.892569268, 2.34816051956   48.892569268
# 17  5.614877e+06  10317.483310   48.8292445005, 2.3265420442  48.8292445005
# 18  5.983446e+06  10704.940490  48.8634605789, 2.40118812928  48.8634605789
# 19  1.824613e+06   6054.936862  48.8625627018, 2.33644336205  48.8625627018
#
#                  1
# 0    2.35071460958
# 1    2.33289799905
# 2    2.42132490078
# 3    2.33745754348
# 4    2.38482096015
# 5    2.29282582242
# 6    2.34280254689
# 7    2.30677699057
# 8     2.3600009859
# 9     2.3800583082
# 10   2.36227244042
# 11   2.36072848785
# 12   2.26197078836
# 13   2.31218769148
# 14   2.35762962032
# 15    2.3125540224
# 16   2.34816051956
# 17    2.3265420442
# 18   2.40118812928
# 19   2.33644336205

# %%
# Now we will rename some columns in order to clarify the dataset

# District : name of the central District for the Arrondissement
# Arrondissement : the Arrondissement or district number which is used to identify it
# Arrondissement_Fr : the descriptive French label for each Arrondissement

paris.rename(columns={'L_AROFF': 'Neighborhood ', 'C_AR': 'Arrondissement_Num', 'L_AR': 'French_Name',0: 'Latitude', 1: 'Longitude'}, inplace=True)

# Clean up the dataset to remove unnecessary columns.
# Some of the columns are for mapping software - not required here.

paris.drop(['N_SQ_AR','C_ARINSEE','N_SQ_CO','SURFACE', 'PERIMETRE', 'Geometry X Y' ], axis=1, inplace=True)
paris['Latitude']= paris['Latitude'].astype(float)
paris['Longitude']=paris['Longitude'].astype(float)
paris
# Out:
#     Arrondissement_Num French_Name        Neighborhood    Latitude  Longitude
# 0                    5   5ème Ardt             Panthéon  48.844443   2.350715
# 1                    6   6ème Ardt           Luxembourg  48.849130   2.332898
# 2                   12  12ème Ardt              Reuilly  48.834974   2.421325
# 3                    9   9ème Ardt                Opéra  48.877164   2.337458
# 4                   19  19ème Ardt      Buttes-Chaumont  48.887076   2.384821
# 5                   15  15ème Ardt            Vaugirard  48.840085   2.292826
# 6                    2   2ème Ardt               Bourse  48.868279   2.342803
# 7                   17  17ème Ardt  Batignolles-Monceau  48.887327   2.306777
# 8                    3   3ème Ardt               Temple  48.862872   2.360001
# 9                   11  11ème Ardt           Popincourt  48.859059   2.380058
# 10                  13  13ème Ardt             Gobelins  48.828388   2.362272
# 11                  10  10ème Ardt             Entrepôt  48.876130   2.360728
# 12                  16  16ème Ardt                Passy  48.860392   2.261971
# 13                   7   7ème Ardt       Palais-Bourbon  48.856174   2.312188
# 14                   4   4ème Ardt       Hôtel-de-Ville  48.854341   2.357630
# 15                   8   8ème Ardt               Élysée  48.872721   2.312554
# 16                  18  18ème Ardt    Buttes-Montmartre  48.892569   2.348161
# 17                  14  14ème Ardt         Observatoire  48.829245   2.326542
# 18                  20  20ème Ardt         Ménilmontant  48.863461   2.401188
# 19                   1    1er Ardt               Louvre  48.862563   2.336443

# %% [markdown]
# #### Localization of Paris and mapping

# %%
# Retrieve the Latitude and Longitude for Paris
from geopy.geocoders import Nominatim 

address = 'Paris'

# Define the user_agent as Paris_explorer
geolocator = Nominatim(user_agent="Paris_explorer")

location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

print('The geographical coordinates of Paris France are {}, {}.'.format(latitude, longitude))
# Out:
# The geographical coordinates of Paris France are 48.8566969, 2.3514616.

# %%
# create map of Paris using the above latitude and longitude values
map_paris = folium.Map(location=[latitude, longitude], zoom_start=12)


# add markers to map
for lat, lng, label in zip(paris['Latitude'], paris['Longitude'], paris['French_Name']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=25,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.3,
        parse_html=False).add_to(map_paris)  
    
map_paris
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Use the Foursquare API to explore the Arrondissements of Paris (Neighborhoods)¶

# %%
CLIENT_ID = 'XCCDCVVKRAGVZY2NAN0QTF4JJPL0P3WEZU3GYEX34Z5O0SAJ' # your Foursquare ID
CLIENT_SECRET = 'LCXXO41WIGRZOJAA0FJDM1UE132ALJHBQF15QUELLHSPB3PQ' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: XCCDCVVKRAGVZY2NAN0QTF4JJPL0P3WEZU3GYEX34Z5O0SAJ
# CLIENT_SECRET:LCXXO41WIGRZOJAA0FJDM1UE132ALJHBQF15QUELLHSPB3PQ

# %%
paris.loc[0, 'French_Name']
# Out:
# '5ème Ardt'

# %%
neighborhood_latitude = paris.loc[0, 'Latitude'] # Neighborhood latitude value
neighborhood_longitude = paris.loc[0, 'Longitude'] # Neighborhood longitude value

neighborhood_name = paris.loc[0, 'French_Name'] # Neighborhood name

LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url # displays the URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=XCCDCVVKRAGVZY2NAN0QTF4JJPL0P3WEZU3GYEX34Z5O0SAJ&client_secret=LCXXO41WIGRZOJAA0FJDM1UE132ALJHBQF15QUELLHSPB3PQ&v=20180605&ll=48.8444431505,2.35071460958&radius=500&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ebf12db69babe001b78f3da'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Panthéon',
#   'headerFullLocation': 'Panthéon, Paris',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 89,
#   'suggestedBounds': {'ne': {'lat': 48.848943155, 'lng': 2.357539657530384},
#    'sw': {'lat': 48.839943145999996, 'lng': 2.3438895616296156}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bca09f70687ef3ba719dbcc',
#        'name': "Au P'tit Grec",
#        'location': {'address': '68 rue Mouffetard',
#         'lat': 48.842858,
#         'lng': 2.349721,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.842858,
#           'lng': 2.349721}],
#         'distance': 190,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'neighborhood': 'place monge',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['68 rue Mouffetard', '75005 Paris', 'France']},
#        'categories': [{'id': '52e81612bcbc57f1066b79f2',
#          'name': 'Creperie',
#          'pluralName': 'Creperies',
#          'shortName': 'Creperie',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/creperie_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bca09f70687ef3ba719dbcc-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc07f772a89ef3b2a91f088',
#        'name': 'Place de la Contrescarpe',
#        'location': {'address': 'Place de la Contrescarpe',
#         'lat': 48.844452870697566,
#         'lng': 2.349397838115692,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.844452870697566,
#           'lng': 2.349397838115692}],
#         'distance': 96,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'neighborhood': 'Jardin des Plantes',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['Place de la Contrescarpe',
#          '75005 Paris',
#          'France']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc07f772a89ef3b2a91f088-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be46ff0910020a1d8b6d114',
#        'name': 'Le Resto',
#        'location': {'address': '8 rue Tournefort',
#         'lat': 48.84396630105313,
#         'lng': 2.3481165634851684,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.84396630105313,
#           'lng': 2.3481165634851684}],
#         'distance': 197,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['8 rue Tournefort', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '76861678'}},
#       'referralId': 'e-0-4be46ff0910020a1d8b6d114-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54469172498ed34e0178dc37',
#        'name': 'Brewberry Bar',
#        'location': {'address': '11 rue du Pot-de-Fer',
#         'lat': 48.84294546857269,
#         'lng': 2.3486221990301255,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.84294546857269,
#           'lng': 2.3486221990301255}],
#         'distance': 226,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['11 rue du Pot-de-Fer', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54469172498ed34e0178dc37-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '509faa1de4b04c46e9d49aad',
#        'name': 'Boulangerie Anthony Bosson',
#        'location': {'address': '2 rue Mouffetard',
#         'lat': 48.84489,
#         'lng': 2.3490977,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.84489,
#           'lng': 2.3490977}],
#         'distance': 128,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['2 rue Mouffetard', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-509faa1de4b04c46e9d49aad-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bad3174f964a520a1373be3',
#        'name': 'La Grange',
#        'location': {'address': '72 rue Mouffetard',
#         'lat': 48.84261760626484,
#         'lng': 2.349700505219827,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.84261760626484,
#           'lng': 2.349700505219827}],
#         'distance': 216,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['72 rue Mouffetard', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bad3174f964a520a1373be3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '509d975be4b04eb23c9ea186',
#        'name': 'Alizée Creperie',
#        'location': {'address': 'Rue du Pot de Fer',
#         'crossStreet': 'La Moufette',
#         'lat': 48.84307022662272,
#         'lng': 2.349200151908759,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.84307022662272,
#           'lng': 2.349200151908759}],
#         'distance': 188,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['Rue du Pot de Fer (La Moufette)',
#          '75005 Paris',
#          'France']},
#        'categories': [{'id': '52e81612bcbc57f1066b79f2',
#          'name': 'Creperie',
#          'pluralName': 'Creperies',
#          'shortName': 'Creperie',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/creperie_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-509d975be4b04eb23c9ea186-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd5e7304e32d13aabb1c180',
#        'name': 'Amorino',
#        'location': {'address': '18 rue Mouffetard',
#         'lat': 48.844285178648434,
#         'lng': 2.349202036857605,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.844285178648434,
#           'lng': 2.349202036857605}],
#         'distance': 112,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['18 rue Mouffetard', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd5e7304e32d13aabb1c180-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cb1aaa41168a09310e73423',
#        'name': 'Han Lim',
#        'location': {'address': '6 rue Blainville',
#         'lat': 48.844537542988974,
#         'lng': 2.3485734170643933,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.844537542988974,
#           'lng': 2.3485734170643933}],
#         'distance': 157,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['6 rue Blainville', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'shortName': 'Korean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cb1aaa41168a09310e73423-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d9227159d0f721eb1a92673',
#        'name': "L'Époque",
#        'location': {'address': '81 rue Cardinal Lemoine',
#         'lat': 48.84475648013681,
#         'lng': 2.3497894406318665,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.84475648013681,
#           'lng': 2.3497894406318665}],
#         'distance': 76,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['81 rue Cardinal Lemoine',
#          '75005 Paris',
#          'France']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d9227159d0f721eb1a92673-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c1d48cd8b3aa59385599a5f',
#        'name': 'El Picaflor',
#        'location': {'address': '9 rue Lacépède',
#         'lat': 48.843704511235536,
#         'lng': 2.353434212717251,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.843704511235536,
#           'lng': 2.353434212717251}],
#         'distance': 215,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['9 rue Lacépède', '75005 Paris', 'France']},
#        'categories': [{'id': '4eb1bfa43b7b52c0e1adc2e8',
#          'name': 'Peruvian Restaurant',
#          'pluralName': 'Peruvian Restaurants',
#          'shortName': 'Peruvian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/peruvian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c1d48cd8b3aa59385599a5f-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c346c4209a99c74e1200c2a',
#        'name': 'Le Volcan',
#        'location': {'address': 'Rue Mouffetard',
#         'crossStreet': 'Rue Thon',
#         'lat': 48.84497087286654,
#         'lng': 2.349154071023857,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.84497087286654,
#           'lng': 2.349154071023857}],
#         'distance': 128,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['Rue Mouffetard (Rue Thon)',
#          '75005 Paris',
#          'France']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c346c4209a99c74e1200c2a-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '527bf21211d2285e6ca8fa26',
#        'name': 'Little Bastards',
#        'location': {'address': '5 rue Blainville',
#         'lat': 48.84452843080229,
#         'lng': 2.3488003104567503,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.84452843080229,
#           'lng': 2.3488003104567503}],
#         'distance': 140,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'neighborhood': 'Sorbonne, Paris',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['5 rue Blainville', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '91086155'}},
#       'referralId': 'e-0-527bf21211d2285e6ca8fa26-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52a6c5a9498e6afa46fbf13b',
#        'name': 'Dose – Dealer de Café',
#        'location': {'address': '73 rue Mouffetard',
#         'lat': 48.8422039324412,
#         'lng': 2.3498297273739035,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.8422039324412,
#           'lng': 2.3498297273739035}],
#         'distance': 257,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['73 rue Mouffetard', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52a6c5a9498e6afa46fbf13b-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e0f90e714956c6285059108',
#        'name': 'Hotel des Nations Saint-Germain',
#        'location': {'address': '54 rue Monge',
#         'lat': 48.84481492289646,
#         'lng': 2.3523505439911307,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.84481492289646,
#           'lng': 2.3523505439911307}],
#         'distance': 126,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['54 rue Monge', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e0f90e714956c6285059108-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda0af964a520273421e3',
#        'name': 'Arènes de Lutèce',
#        'location': {'address': '49 rue Monge',
#         'crossStreet': 'Rue de Navarre',
#         'lat': 48.84509009536325,
#         'lng': 2.3528873920440674,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.84509009536325,
#           'lng': 2.3528873920440674}],
#         'distance': 174,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['49 rue Monge (Rue de Navarre)',
#          '75005 Paris',
#          'France']},
#        'categories': [{'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'shortName': 'Historic Site',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda0af964a520273421e3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c23cc37f1272d7f590182c5',
#        'name': 'Oi Sushi',
#        'location': {'address': '8 rue Mouffetard',
#         'lat': 48.84475911405908,
#         'lng': 2.3493067161990298,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.84475911405908,
#           'lng': 2.3493067161990298}],
#         'distance': 108,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['8 rue Mouffetard', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c23cc37f1272d7f590182c5-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '548b61b7498e6b13e9fecee2',
#        'name': 'LeFoodist',
#        'location': {'address': '59 Rue Cardinal Lemoine',
#         'lat': 48.846319421971934,
#         'lng': 2.351234402659239,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.846319421971934,
#           'lng': 2.351234402659239}],
#         'distance': 212,
#         'postalCode': '75015',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['59 Rue Cardinal Lemoine',
#          '75015 Paris',
#          'France']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-548b61b7498e6b13e9fecee2-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51855085498edeec02bca1ee',
#        'name': 'Bières Cultes',
#        'location': {'address': '44 rue des Boulangers',
#         'crossStreet': 'Rue Monge',
#         'lat': 48.84640553948485,
#         'lng': 2.3518358059841193,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.84640553948485,
#           'lng': 2.3518358059841193}],
#         'distance': 233,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['44 rue des Boulangers (Rue Monge)',
#          '75005 Paris',
#          'France']},
#        'categories': [{'id': '4bf58dd8d48988d186941735',
#          'name': 'Liquor Store',
#          'pluralName': 'Liquor Stores',
#          'shortName': 'Liquor Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51855085498edeec02bca1ee-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dc9a399cc3f7691c5426f30',
#        'name': 'Au Vieux Cèdre',
#        'location': {'address': '2 rue Blainville',
#         'lat': 48.84454112944525,
#         'lng': 2.3489901423454285,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.84454112944525,
#           'lng': 2.3489901423454285}],
#         'distance': 126,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['2 rue Blainville', '75005 Paris', 'France']},
#        'categories': [{'id': '58daa1558bbb0b01f18ec1cd',
#          'name': 'Lebanese Restaurant',
#          'pluralName': 'Lebanese Restaurants',
#          'shortName': 'Lebanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dc9a399cc3f7691c5426f30-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '507061a0e4b08bafd1a29eeb',
#        'name': 'Crazy Pasta',
#        'location': {'address': '4 Rue Blainville',
#         'lat': 48.844480694632594,
#         'lng': 2.348822233776467,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.844480694632594,
#           'lng': 2.348822233776467}],
#         'distance': 138,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['4 Rue Blainville', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-507061a0e4b08bafd1a29eeb-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '517c14d2e4b0eef574ad0b91',
#        'name': 'Casa Hugo',
#        'location': {'address': '48 rue Monge',
#         'lat': 48.84510364869614,
#         'lng': 2.3521898310752545,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.84510364869614,
#           'lng': 2.3521898310752545}],
#         'distance': 130,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['48 rue Monge', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-517c14d2e4b0eef574ad0b91-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cd7098c67adf04d183c3691',
#        'name': 'La Crète',
#        'location': {'address': '85-87 rue Mouffetard',
#         'lat': 48.841791616415264,
#         'lng': 2.3497529272313087,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.841791616415264,
#           'lng': 2.3497529272313087}],
#         'distance': 303,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['85-87 rue Mouffetard', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'shortName': 'Greek',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cd7098c67adf04d183c3691-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b2abc97f964a5208fae24e3',
#        'name': 'Place Monge',
#        'location': {'address': 'Place Monge',
#         'lat': 48.842911,
#         'lng': 2.35173,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.842911,
#           'lng': 2.35173}],
#         'distance': 186,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['Place Monge', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b2abc97f964a5208fae24e3-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6b21c2f964a520e7f42be3',
#        'name': 'Foyer Vietnam',
#        'location': {'address': '74-80 rue Monge',
#         'lat': 48.842187,
#         'lng': 2.351987,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.842187,
#           'lng': 2.351987}],
#         'distance': 267,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['74-80 rue Monge', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d14a941735',
#          'name': 'Vietnamese Restaurant',
#          'pluralName': 'Vietnamese Restaurants',
#          'shortName': 'Vietnamese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6b21c2f964a520e7f42be3-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd305229854d13a2dabfc4d',
#        'name': "L'Arbre à Cannelle",
#        'location': {'address': '14 rue Linné',
#         'lat': 48.844852941819774,
#         'lng': 2.3547499304522,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.844852941819774,
#           'lng': 2.3547499304522}],
#         'distance': 299,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['14 rue Linné', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'shortName': 'Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd305229854d13a2dabfc4d-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54842e01498ee191fa3c80e8',
#        'name': 'Strada Café',
#        'location': {'address': '24 rue Monge',
#         'lat': 48.847037811343526,
#         'lng': 2.351278439067274,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.847037811343526,
#           'lng': 2.351278439067274}],
#         'distance': 291,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['24 rue Monge', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54842e01498ee191fa3c80e8-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dc2f90718387d1bd4fde611',
#        'name': 'Lilane',
#        'location': {'address': '8 rue Gracieuse',
#         'lat': 48.84218097406017,
#         'lng': 2.3516297926914502,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.84218097406017,
#           'lng': 2.3516297926914502}],
#         'distance': 260,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['8 rue Gracieuse', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dc2f90718387d1bd4fde611-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5214950411d211edf8255ff9',
#        'name': 'Kokoro',
#        'location': {'address': '36 rue des Boulangers',
#         'lat': 48.846202,
#         'lng': 2.35227,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.846202,
#           'lng': 2.35227}],
#         'distance': 226,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['36 rue des Boulangers',
#          '75005 Paris',
#          'France']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5214950411d211edf8255ff9-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e4a8e38fa76a0c058d14d02',
#        'name': 'Mococha',
#        'location': {'address': '89 rue Mouffetard',
#         'lat': 48.841719,
#         'lng': 2.349762,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.841719,
#           'lng': 2.349762}],
#         'distance': 311,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['89 rue Mouffetard', '75005 Paris', 'France']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b31',
#          'name': 'Chocolate Shop',
#          'pluralName': 'Chocolate Shops',
#          'shortName': 'Chocolate Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/candystore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e4a8e38fa76a0c058d14d02-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5535621c498ec2336c36ed7f',
#        'name': 'Nossa Churrasqueira',
#        'location': {'address': "1 rue de l'École Polytechnique",
#         'lat': 48.8473706224662,
#         'lng': 2.3481693863868713,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.8473706224662,
#           'lng': 2.3481693863868713}],
#         'distance': 375,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ["1 rue de l'École Polytechnique",
#          '75005 Paris',
#          'France']},
#        'categories': [{'id': '4def73e84765ae376e57713a',
#          'name': 'Portuguese Restaurant',
#          'pluralName': 'Portuguese Restaurants',
#          'shortName': 'Portuguese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '127412291'}},
#       'referralId': 'e-0-5535621c498ec2336c36ed7f-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda09f964a520ea3321e3',
#        'name': 'Panthéon',
#        'location': {'address': 'Place du Panthéon',
#         'lat': 48.846229,
#         'lng': 2.346084,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.846229,
#           'lng': 2.346084}],
#         'distance': 393,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['Place du Panthéon', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d12d941735',
#          'name': 'Monument / Landmark',
#          'pluralName': 'Monuments / Landmarks',
#          'shortName': 'Landmark',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_monument_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda09f964a520ea3321e3-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb48ab287aa9521543cadd1',
#        'name': 'Le Buisson Ardent',
#        'location': {'address': '25 rue Jussieu',
#         'lat': 48.84684625433147,
#         'lng': 2.3542102424629405,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.84684625433147,
#           'lng': 2.3542102424629405}],
#         'distance': 370,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['25 rue Jussieu', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb48ab287aa9521543cadd1-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f5b7b0ce4b085f52d435633',
#        'name': 'Les Arènes',
#        'location': {'address': '16 rue Linné',
#         'lat': 48.844979573155804,
#         'lng': 2.3547101863233513,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.844979573155804,
#           'lng': 2.3547101863233513}],
#         'distance': 298,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['16 rue Linné', '75005 Paris', 'France']},
#        'categories': [{'id': '52e81612bcbc57f1066b79f1',
#          'name': 'Bistro',
#          'pluralName': 'Bistros',
#          'shortName': 'Bistro',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '132675394'}},
#       'referralId': 'e-0-4f5b7b0ce4b085f52d435633-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5530cc1f498ea6903c33a3da',
#        'name': 'Bonvivant',
#        'location': {'address': '7 rue des Écoles',
#         'lat': 48.84755082513145,
#         'lng': 2.3519687354564667,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.84755082513145,
#           'lng': 2.3519687354564667}],
#         'distance': 357,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['7 rue des Écoles', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d123941735',
#          'name': 'Wine Bar',
#          'pluralName': 'Wine Bars',
#          'shortName': 'Wine Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5530cc1f498ea6903c33a3da-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b8a75d1f964a520a96d32e3',
#        'name': 'Grand Action',
#        'location': {'address': '5 rue des Écoles',
#         'lat': 48.84761412154862,
#         'lng': 2.352290695489145,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.84761412154862,
#           'lng': 2.352290695489145}],
#         'distance': 371,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['5 rue des Écoles', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d17e941735',
#          'name': 'Indie Movie Theater',
#          'pluralName': 'Indie Movie Theaters',
#          'shortName': 'Indie Movies',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b8a75d1f964a520a96d32e3-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b924294f964a520d2ee33e3',
#        'name': 'Godjo',
#        'location': {'address': "8 rue de l'École Polytechnique",
#         'lat': 48.84757960167134,
#         'lng': 2.3479842647566334,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.84757960167134,
#           'lng': 2.3479842647566334}],
#         'distance': 402,
#         'postalCode': '75006',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': '75005',
#         'country': 'France',
#         'formattedAddress': ["8 rue de l'École Polytechnique",
#          '75006 Paris',
#          'France']},
#        'categories': [{'id': '4bf58dd8d48988d10a941735',
#          'name': 'Ethiopian Restaurant',
#          'pluralName': 'Ethiopian Restaurants',
#          'shortName': 'Ethiopian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ethiopian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b924294f964a520d2ee33e3-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55955697498e6e3d3531398c',
#        'name': 'Extra Life',
#        'location': {'address': '9 passage des Patriaches',
#         'lat': 48.8411581083408,
#         'lng': 2.3501838871069127,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.8411581083408,
#           'lng': 2.3501838871069127}],
#         'distance': 367,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['9 passage des Patriaches',
#          '75005 Paris',
#          'France']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55955697498e6e3d3531398c-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda11f964a520f63521e3',
#        'name': 'Mavrommátis',
#        'location': {'address': '42 rue Daubenton',
#         'lat': 48.84056933181091,
#         'lng': 2.3511841893196106,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.84056933181091,
#           'lng': 2.3511841893196106}],
#         'distance': 432,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['42 rue Daubenton', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'shortName': 'Greek',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda11f964a520f63521e3-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda05f964a520523221e3',
#        'name': 'Le Piano Vache',
#        'location': {'address': '8 rue Laplace',
#         'lat': 48.847266816912025,
#         'lng': 2.347707272470676,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.847266816912025,
#           'lng': 2.347707272470676}],
#         'distance': 383,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['8 rue Laplace', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'shortName': 'Pub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda05f964a520523221e3-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53d6a34b498e8c6d9d29d133',
#        'name': 'La Table de Geneviève',
#        'location': {'address': '8 rue Descartes',
#         'lat': 48.847235099264985,
#         'lng': 2.3486005809027803,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.847235099264985,
#           'lng': 2.3486005809027803}],
#         'distance': 347,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['8 rue Descartes', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53d6a34b498e8c6d9d29d133-40'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58c5a319730a92753525b080',
#        'name': 'I Lazzari',
# ...
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ff190f1e4b01885368e4fa4',
#        'name': 'Il Golosone',
#        'location': {'address': '32 Rue des Carmes',
#         'lat': 48.848034200506625,
#         'lng': 2.3471908305229365,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.848034200506625,
#           'lng': 2.3471908305229365}],
#         'distance': 475,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['32 Rue des Carmes', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ff190f1e4b01885368e4fa4-75'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b28ab39f964a5208e9424e3',
#        'name': 'Hôtel Quartier Latin',
#        'location': {'address': '9 rue des Ecoles',
#         'crossStreet': "rue d'Arras",
#         'lat': 48.847689428222026,
#         'lng': 2.3518526659901298,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.847689428222026,
#           'lng': 2.3518526659901298}],
#         'distance': 370,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ["9 rue des Ecoles (rue d'Arras)",
#          '75005 Paris',
#          'France']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b28ab39f964a5208e9424e3-76'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e8c3888b634adfa528c3821',
#        'name': 'Labyrinthe du Jardin des Plantes',
#        'location': {'address': 'Jardin des Plantes',
#         'lat': 48.84313030631581,
#         'lng': 2.3559548233635734,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.84313030631581,
#           'lng': 2.3559548233635734}],
#         'distance': 410,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['Jardin des Plantes', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d15a941735',
#          'name': 'Garden',
#          'pluralName': 'Gardens',
#          'shortName': 'Garden',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e8c3888b634adfa528c3821-77'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d066b26a268548184c1c1bd',
#        'name': 'Brava Pizza',
#        'location': {'address': '38 rue du Cardinal Lemoine',
#         'lat': 48.847097,
#         'lng': 2.352097,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.847097,
#           'lng': 2.352097}],
#         'distance': 312,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['38 rue du Cardinal Lemoine',
#          '75005 Paris',
#          'France']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d066b26a268548184c1c1bd-78'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4da358719935a093827dc76f',
#        'name': 'Restaurant Pacha',
#        'location': {'address': '4 bis rue des Écoles',
#         'lat': 48.84779890255509,
#         'lng': 2.3516445930053718,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.84779890255509,
#           'lng': 2.3516445930053718}],
#         'distance': 379,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['4 bis rue des Écoles', '75005 Paris', 'France']},
#        'categories': [{'id': '5283c7b4e4b094cb91ec88d7',
#          'name': 'Kebab Restaurant',
#          'pluralName': 'Kebab Restaurants',
#          'shortName': 'Kebab',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4da358719935a093827dc76f-79'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda02f964a520903121e3',
#        'name': 'Hôtel Vendome Saint Germain',
#        'location': {'address': "8 Rue d'Arras",
#         'lat': 48.847393416890974,
#         'lng': 2.3515353586303633,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.847393416890974,
#           'lng': 2.3515353586303633}],
#         'distance': 333,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ["8 Rue d'Arras", '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda02f964a520903121e3-80'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b2aa9d88d0a53002c726ec5',
#        'name': 'Les Belles Plantes',
#        'location': {'address': '47 Rue Cuvier',
#         'lat': 48.8446155,
#         'lng': 2.3569026,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.8446155,
#           'lng': 2.3569026}],
#         'distance': 453,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['47 Rue Cuvier', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b2aa9d88d0a53002c726ec5-81'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bde7569ffdec92829cae8a1',
#        'name': "Galerie des Enfants du Muséum d'Histoire Naturelle",
#        'location': {'address': "Grande Galerie de l'Évolution",
#         'crossStreet': '36 rue Geoffroy Saint-Hilaire',
#         'lat': 48.84210226236579,
#         'lng': 2.3561784625053406,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.84210226236579,
#           'lng': 2.3561784625053406}],
#         'distance': 477,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ["Grande Galerie de l'Évolution (36 rue Geoffroy Saint-Hilaire)",
#          '75005 Paris',
#          'France']},
#        'categories': [{'id': '4bf58dd8d48988d191941735',
#          'name': 'Science Museum',
#          'pluralName': 'Science Museums',
#          'shortName': 'Science Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_science_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bde7569ffdec92829cae8a1-82'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc7a9f014d795216be067e9',
#        'name': 'Tim Hotel',
#        'location': {'lat': 48.84392102471058,
#         'lng': 2.3549125864182154,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.84392102471058,
#           'lng': 2.3549125864182154}],
#         'distance': 312,
#         'cc': 'FR',
#         'country': 'France',
#         'formattedAddress': ['France']},
#        'categories': [{'id': '4bf58dd8d48988d1ee931735',
#          'name': 'Hostel',
#          'pluralName': 'Hostels',
#          'shortName': 'Hostel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc7a9f014d795216be067e9-83'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c7916b3794e224bc61f6428',
#        'name': 'Girasole',
#        'location': {'address': '4 rue Linné',
#         'lat': 48.84396764549877,
#         'lng': 2.3549531116869713,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.84396764549877,
#           'lng': 2.3549531116869713}],
#         'distance': 314,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['4 rue Linné', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c7916b3794e224bc61f6428-84'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57506c87498e3621485be024',
#        'name': 'Le Passage',
#        'location': {'address': '46 rue des Fossés Saint-Bernard',
#         'lat': 48.84766362383736,
#         'lng': 2.3526352643966675,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.84766362383736,
#           'lng': 2.3526352643966675}],
#         'distance': 385,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['46 rue des Fossés Saint-Bernard',
#          '75005 Paris',
#          'France']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57506c87498e3621485be024-85'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f4d34d6e4b0ed36931daec3',
#        'name': "Pizza Roma d'Amore Mio",
#        'location': {'address': '13 rue Linné',
#         'lat': 48.84450874389399,
#         'lng': 2.3548829511230567,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.84450874389399,
#           'lng': 2.3548829511230567}],
#         'distance': 305,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['13 rue Linné', '75005 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f4d34d6e4b0ed36931daec3-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d989406e07ea35defeaf402',
#        'name': 'La Fontaine',
#        'location': {'lat': 48.843898753817506,
#         'lng': 2.3551706786021613,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.843898753817506,
#           'lng': 2.3551706786021613}],
#         'distance': 332,
#         'cc': 'FR',
#         'country': 'France',
#         'formattedAddress': ['France']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d989406e07ea35defeaf402-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fa54dc3e4b039aeeb45380d',
#        'name': "Collection de mineraux de l'université Pierre et Marie Curie",
#        'location': {'address': 'UPMC – Paris VI',
#         'crossStreet': '4 place Jussieu',
#         'lat': 48.84634686927579,
#         'lng': 2.3553013801574707,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.84634686927579,
#           'lng': 2.3553013801574707}],
#         'distance': 397,
#         'postalCode': '75005',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['UPMC – Paris VI (4 place Jussieu)',
#          '75005 Paris',
#          'France']},
#        'categories': [{'id': '4bf58dd8d48988d191941735',
#          'name': 'Science Museum',
#          'pluralName': 'Science Museums',
#          'shortName': 'Science Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_science_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fa54dc3e4b039aeeb45380d-88'}]}]}}
